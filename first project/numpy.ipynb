# %%
import numpy as np, matplotlib.pyplot as plt
piplot=np.linspace(0, 2 * np.pi, 100)
sinplot = np.sin(piplot)
cosplot = np.cos(piplot)
tanplot = np.tan(piplot)

# %%
plt.plot(piplot, sinplot)

# %%
plt.plot(piplot, cosplot)

# %%
plt.plot(piplot, tanplot)
